# %% [markdown]
# <h1 style="color:saddlebrown;"><center>Data Science based Course Modules For Digital Forensics</center></h1>

# %% [markdown]
# <h3 style="color:darkolivegreen;"><center>[Created By Capstone Team CS 23-314]</center></h3>

# %% [markdown]
# <hr style="height:2%;width:80%;">

# %% [markdown]
# <div>
#     <img src="attachment:cspic2.jpg" width="300">
# </div>

# %% [markdown]
# <hr style="height:0.5%;width:80%">
# <h2 style="color:darkcyan;"><center><u>[Welcome!]</u></center><h2>

# %% [markdown]
# <p><center>With these modules you will get to simulate the investigation and working of real-world criminal cases as a digital forensics investigator, with data science as your pioneering tool! <br><blockquote style="color:cadetblue;">These are meant to be beginner friendly, so don't be intimidated! We'll get your started in the right direction.</blockquote></center><p>

# %% [markdown]
# <br>
# <h2 style="color:peru;"><center><u>[Background]</u></center></h2>

# %% [markdown]
# <p><center>As technology advances, so do the ways in which criminals can attempt to out maneuver law enforcement. As technology advances so do the ways in which criminals can attempt to out maneuver law enforcement.
# <blockquote style="color:burlywood;">This can come in a vast variety of different forms, from encrypted communication to third party apps to sneaky financial transactions.</blockquote>
# The possibilities have become nearly limitless, with the criminal world constantly racing to be one step ahead of the law. However, that fuels the motivation of the digital forensics field to hone and advance their tool kit to better combat and undermine the criminal entities.
# <blockquote style="color:burlywood">Interception has become a key principal, and deciphering a necessary tool, both heartily receptive to data science practices.</blockquote>
# Within data science, with the right queries and analysis, many criminal streams of production can be infiltrated. This can be made possible by embedding machine learning programs into the forensic repertoire. Instead of needing manual combing of hefty data sets, one can streamline the process and teach the program to pull out critical and suspicious data, heavily decreasing the time it takes to sift through the harmless clutter.
# <blockquote style="color:burlywood">With areas of note being able to be identified much quicker, personnel can then narrow their focus and save resources on unnecessary investigation.</blockquote>
# Aiding the next generation of digital forensic investigators also aids in strengthening the nation's security and criminal reduction.</center></p>

# %% [markdown]
# <div>
#     <img src="attachment:cspic1.jpg" width="400">
# </div>

# %% [markdown]
# <h2 style="color:mediumpurple;"><center><u>[Learning roadmap]</u></center></h2>

# %% [markdown]
# <p><center>We will teach you how to create, manipulate and utilize jupyter notebooks for machine learning driven digital forensic investigation.
# <blockquote style="color:thistle;">Machine learning and data science will be used interchangeably throughout these notebooks. Also to note! these tutorials are <b>made</b> with jupyter notebooks! </blockquote>
# </center></p>

# %% [markdown]
# <h3><center><b style="color:indigo;">What's on the agenda:</b></center><h3>

# %% [markdown]
# <dl style="text-align:center;list-style-position:inside">
#     <dt><u>Software needed</u></dt>
#     <dd style="color:darkviolet;">What you'll need for all your machine learning desires!</dd>
#     <dt>Creation</dt>
#     <dd style="color:darkviolet;">How to get the jupyter notebook up, running and opened</dd>
#     <dt>Manipulation</dt>
#     <dd style="color:plum;">Quick pointers on how to edit and handle the notebook</dd>
#     <dt>Utilization</dt>
#     <dd style="color:plum;">Main goal! How to get the notebook to do what you intend</dd>
#     <dt>Chat logs</dt>
#     <dd style="color:skyblue;">Notebook is ready, learn how to utilize for chat log investigation</dd>
#     <dt>Images</dt>
#     <dd style="color:skyblue;">Notebook is ready, learn how to utilize for image investigation</dd>
#     <dt>Analysis</dt>
#     <dd style="color:lightblue;">We now have the data, but what does it mean?</dd>
#     <dt>Export/Sharing</dt>
#     <dd style="color:lightblue;">You've caught the bad guy! Now time to share to the team for action</dd>
# </dl>
